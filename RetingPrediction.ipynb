# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from nltk.tokenize import WordPunctTokenizer
from nltk.stem import SnowballStemmer
from string import punctuation
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from xgboost.sklearn import XGBClassifier
from sklearn.metrics import mean_squared_error, mean_absolute_error, median_absolute_error

# %%
# Read data
data = pd.read_csv("X_train.csv")

# %%
data
# Out:
#             sku  categoryLevel1Id  categoryLevel2Id  brandId  \
# 0      20005023               401           4010201      826
# 1      20020647               403           4030101     1425
# 2      20020701               401           4010401      124
# 3      30012256               203           2030301       93
# 4      30011341               205           2050201      656
# 5      20023626               405           4050102      829
# 6      30011639               203           2030201      995
# 7      20022938               404           4040203      759
# 8      20007867               406           4060101       48
# 9      20002766               412           4120101       11
# 10     20006244               406           4060301       62
# 11     20008579               407           4070101       80
# 12     20023664               404           4040204      879
# 13     20003446               410           4100301       48
# 14     40030029               304           3040304        1
# 15     20023358               405           4050102      617
# 16     30011141               207           2070202     1008
# 17     50006546               516           5160401      109
# 18     20006918               405           4050301      879
# 19     30010960               207           2070202       11
# 20     10000086               107           1070902       10
# 21     10000422               107           1070908       80
# 22     50034934               103           1030901      767
# 23     30010919               207           2070202       11
# 24     20021708               401           4010301       53
# 25     20020810               401           4010101      863
# 26     20021872               406           4060301       62
# 27     20007977               406           4061101       86
# 28     20022045               411           4110101       13
# 29     20022087               411           4110102      617
# ...         ...               ...               ...      ...
# 15557  20006232               412           4120101       62
# 15558  20023488               406           4060501      879
# 15559  20000670               403           4030101      308
# 15560  30010612               205           2050101      498
# 15561  20022415               406           4060601      879
# 15562  20008127               403           4030101       57
# 15563  20008657               405           4050104      973
# 15564  20025040               408           4080101     1440
# 15565  20023957               406           4061001      617
# 15566  20021311               411           4110102      937
# 15567  40055599               303           3030601     1542
# 15568  30011142               207           2070202     1008
# 15569  20021192               411           4110103     1050
# 15570  20020620               403           4030101     1425
# 15571  20007573               401           4010201     1020
# 15572  20008445               406           4061101       11
# 15573  20022973               404           4040203      759
# 15574  20021828               413           4130401       63
# 15575  20022158               413           4130401       11
# 15576  20003608               406           4060501       62
# 15577  20023790               408           4080101      939
# 15578  20005530               401           4010301       81
# 15579  20004224               406           4061101       62
# 15580  11031399               107           1070907       80
# 15581  30011628               203           2030201      440
# 15582  20002015               403           4030201     2159
# 15583  20023927               405           4050303      638
# 15584  20021363               411           4110102       48
# 15585  20022009               405           4050104      617
# 15586  50035051               515           5150101       11
#
#                                                 property  \
# 0      [{34: 'f982777489055c6563d68c005fd24aad'}, {36...
# 1      [{34: '9ce895413ebdf6b6dcb69b07dc782591'}, {36...
# 2      [{34: '9ce895413ebdf6b6dcb69b07dc782591'}, {36...
# 3      [{34: '9ce895413ebdf6b6dcb69b07dc782591'}, {36...
# 4      [{34: '9ce895413ebdf6b6dcb69b07dc782591'}, {36...
# 5      [{12671: 'e04af96afe53462f72f39331b209a810'}, ...
# 6      [{34: '9ce895413ebdf6b6dcb69b07dc782591'}, {36...
# 7      [{897: 'e4da3b7fbbce2345d7772b0674a318d5'}, {2...
# 8      [{769: '6b101662e3fb18552fa38924077c789a'}, {1...
# 9      [{34: 'f982777489055c6563d68c005fd24aad'}, {36...
# 10     [{34: 'f982777489055c6563d68c005fd24aad'}, {36...
# 11     [{34: '9ce895413ebdf6b6dcb69b07dc782591'}, {36...
# 12     [{34: '9ce895413ebdf6b6dcb69b07dc782591'}, {36...
# 13     [{439: '3cfcdd17dfddb03e17fb5cd09a571502'}, {3...
# 14     [{34: '9ce895413ebdf6b6dcb69b07dc782591'}, {36...
# 15     [{12590: 'd6c153249031cfb763929c15dc245694'}, ...
# 16     [{3: '26657d5ff9020d2abefe558796b99584'}, {1: ...
# 17     [{34: '7e9669405ffffb748b1478cd6c0ab102'}, {36...
# 18     [{34: 'f982777489055c6563d68c005fd24aad'}, {36...
# 19     [{439: '3cfcdd17dfddb03e17fb5cd09a571502'}, {1...
# 20     [{9928: 'e04af96afe53462f72f39331b209a810'}, {...
# 21     [{34: '9ce895413ebdf6b6dcb69b07dc782591'}, {36...
#
#
#                                                  comment  \
# 0      2,5 года работала и все...устала! Лампочка гор...
# 1      Через 2 месяца после истечении гарантийного ср...
# 2      пользуюсь уже три недели. нареканий ни каких н...
# 3      Ребят этот системный блок подойдёт для игры кс...
# 4      я считаю, что яри замечательный телефон! Прият...
# 5      Сегодня купила 2 таких вентилятора! Ужасный. С...
# 6      привезли ноут, по качеству корпуса и дизайну 5...
# 7      Купила этот увлажнитель, шумный, подсветка меш...
# 8      Комбайн отличный. Пользуюсь 2 года. Пользуюсь ...
# 9      Отличный аппарат. авто выключение вообще преле...
# 10     Смотрели сегодня эту модель в магазине, сначал...
# 11     Пользуюсь больше года, печь с самого начала пл...
# 12     Пользуемся с женой вот уже несколько месяцев и...
# 13     высокая скорость, мало шума, приемлемая цена, ...
# 14     Мне купили ПСП на день рождения,когда мне испо...
# 15     Пользуюсь неделю, нареканий ни каких нет. Собр...
# 16     если те впарили шляпу то не надо наговаривать!...
# 17     Ужасная некачественная сборка, мне попался с н...
# 18     Использую уже 2 года.  В принципе доволен. Охл...
# 19     Огромный минус - отсутствие радио. А так был б...
# 20     Прекрасный телевизор!!!Качество изображения на...
# 21     Плазма супер за такую цену, качество класс, фи...
# 22     На нормальный усилитель такие провода ставить ...
# 23     расскажу историю, сами решайте, покупать или н...
# 24     Приобрела 2 месяца назад. До покупки имела опы...
# 25     В целом неплохая газовая панель. Поверхность в...
# 26     Мы приобрели ее более 2-х лет назад, в подарок...
# 27     Сегодня с мужем приобрели в М.видео электроотк...
# 28     Отвратительный пылесос, лучше бы мы не покупал...
# 29     Пользуюсь данным пылесосом больше восьми месяц...
# ...                                                  ...
# 15557                Очень плохо скользит подошва утюга!
# 15558  Отличная соковыжималка! Очень долго искал что-...
# 15559  Как сказала жена: это машина, которая все отст...
# 15560  по началу боялся того, что купил этот аппарат,...
# 15561                           Для борка даже не дорого
# 15562  Очень неплохая стиральная машина за невысокую ...
# 15563  Плюсы:  - Низкая цена  - Приятный дизайн  - До...
# 15564  Очень нравится эта плита: и по стилю, и по фун...
# 15565  Хороший чайник нет запаха , медленно образовыв...
# 15566  доволен до безумия! до него было много моделей...
# 15567  Купила дочке 10 лет - довольна, много уровней,...
# 15568  Плеер хороший, видео, музыка, всё отлично рабо...
# 15569  Прекрасный пылесос, сухая уборка одно, а после...
# 15570  10 лет проработала предыдущая машина Zanussi -...
# 15571     Купили недавно данную вытяжку, очень довольны!
# 15572  Пароварка очень порадовала!! Пользуюсь ей уже ...
# 15573  Воды в резервуаре хватает примерно на 5-6 дней...
# 15574  Пользуюсь уже года 3 каждое утро, отличный про...
# 15575  При использовании первые три года вопросов к ф...
# 15576  Очень хорошая соковыжималка, от ее стоимости ч...
# 15577  Народ, при доставке обращайте внимание на цвет...
# 15578  Суровые немцы из Электролюкса порадовали в оче...
# 15579  Хорошая модель йогуртница, вместимость конечно...
# 15580  Достоинства: Цена. Нужен был белый ТВ на кухню...
# 15581  Подскажите мне.Каков этот комп для игр?Наприме...
# 15582  Не плохая машинка за такие деньги. Очень хорош...
# 15583  Отличный кондиционер, работает тихо,в режиме н...
# 15584  Пылесос отличный. Мощный-это раз. Не по-детски...
# 15585                                       Три скорости
# 15586  Думал что у меня голова не стандартная, но эти...
#
#                                          commentNegative  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13     практически нет. Брала для помола специй, в ча...
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 15557                                                NaN
# 15558                                                NaN
# 15559                                                NaN
# 15560                                                NaN
# 15561                                                Нет
# 15562                                                NaN
# 15563                                                NaN
# 15564                                                NaN
# 15565                                                NaN
# 15566                                                NaN
# 15567                                                NaN
# 15568                                                NaN
# 15569                                                NaN
# 15570                                                NaN
# 15571                                                NaN
# 15572                                                NaN
# 15573  Шум: работает как старый компьютер с неисправн...
# 15574                                                NaN
# 15575                                                NaN
# 15576                                                NaN
# 15577                                                NaN
# 15578                                                NaN
# 15579                                                NaN
# 15580                                                NaN
# 15581                                                NaN
# 15582                                                NaN
# 15583                                                NaN
# 15584                                                NaN
# 15585                   Издаёт зловоние во время работы.
# 15586                                                NaN
#
#                                          commentPositive
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13     Пользуюсь данной кофемолкой несколько месяцев ...
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 15557                                                NaN
# 15558                                                NaN
# 15559                                                NaN
# 15560                                                NaN
# 15561  С утра слегка поджаренный тост со сливочным ма...
# 15562                                                NaN
# 15563                                                NaN
# 15564                                                NaN
# 15565                                                NaN
# 15566                                                NaN
# 15567                                                NaN
# 15568                                                NaN
# 15569                                                NaN
# 15570                                                NaN
# 15571                                                NaN
# 15572                                                NaN
# 15573  При покупке обращайте внимание на габариты, ув...
# 15574                                                NaN
# 15575                                                NaN
# 15576                                                NaN
# 15577                                                NaN
# 15578                                                NaN
# 15579                                                NaN
# 15580                                                NaN
# 15581                                                NaN
# 15582                                                NaN
# 15583                                                NaN
# 15584                                                NaN
# 15585  Продал я сегодня этот вентилятор с рук.   При ...
# 15586                                                NaN
#
# [15587 rows x 11 columns]

# %%
comments = data["comment"].values
comments_pos = data["commentPositive"].values
comments_neg = data["commentNegative"].values
ratings = data["reting"].values

# %%
neg_inds = np.arange(comments_neg.size)[~pd.isnull(comments_neg)]
pos_inds = np.arange(comments_pos.size)[~pd.isnull(comments_pos)]

# %%
# Merge all comments with positive and negative ones
split_array = np.array([' ' for _ in range(comments.size)])
comments[neg_inds] += split_array[neg_inds] + comments_neg[neg_inds]
comments[pos_inds] += split_array[pos_inds] + comments_pos[pos_inds]

# %%
# Some enhancements
word_punct_tokenizer = WordPunctTokenizer()
snowball_stemmer = SnowballStemmer("russian")

for i in range(comments.size):
    comments[i] = ' '.join([snowball_stemmer.stem(word) for word in word_punct_tokenizer.tokenize(comments[i]) if word not in punctuation])

# %%
# Train-test inds split
train_inds, test_inds = train_test_split(np.arange(ratings.size), test_size=0.33, random_state=42)

# %%
X_train, y_train = comments[train_inds], ratings[train_inds]
X_test, y_test = comments[test_inds], ratings[test_inds]

# %%
# Some tf-idf
vectorizer = TfidfVectorizer(max_df=0.95)  
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

# %%
vectorizer.vocabulary_
# Out:
# {'пережима': 13504,
#  'услыш': 20335,
#  'блик': 4063,
#  'денежк': 6337,
#  'l110': 2264,
#  'включаеш': 4764,
#  'высочен': 5603,
#  'вскрыва': 5186,
#  'вылезет': 5455,
#  'продегустирова': 16041,
#  'залог': 7509,
#  '2a': 523,
#  'топк': 19638,
#  'n97': 2493,
#  'дисков': 6488,
#  'худеет': 20963,
#  'пошив': 15280,
#  'оче': 13164,
#  'жироуловител': 7112,
#  'txt': 3071,
#  'удра': 20092,
#  'ext1': 1878,
#  'джостик': 6432,
#  'трубк': 19823,
#  'архаичн': 3667,
#  'надп': 10876,
#  'монстрик': 10559,
#  'грудинк': 6106,
#  'fs21': 1960,
#  'принцип': 15768,
#  'коллекторн': 8999,
#  'micke': 2400,
#  'помешива': 14810,
#  'поинт': 14543,
#  'богс': 4103,
#  'заеха': 7360,
#  'изыска': 8229,
#  'чашечк': 21101,
#  'перемалова': 13562,
#  'достанет': 6741,
#  'крик': 9453,
#  'шум': 21485,
#  'azurexcel': 1420,
#  'триколоровск': 19797,
#  'ном': 11905,
#  'выбра': 5308,
#  'гремет': 6063,
#  'сутк': 19167,
#  'blu': 1489,
#  'негреет': 11362,
#  'начальник': 11254,
#  'двухсторон': 6263,
#  'усбшник': 20312,
#  'подставочк': 14397,
#  'стиран': 18982,
#  'прогон': 16002,
#  'bolsho': 1503,
#  'неиспользова': 11463,
#  'преложен': 15456,
#  'высоковат': 5587,
#  'rising': 2768,
#  'nft': 2517,
#  'девушк': 6283,
#  'третьесортн': 19763,
#  'сверхъестествен': 17711,
#  'миcрософт': 10333,
#  'козел': 8960,
#  'обммsт': 12115,
#  'царапк': 20982,
#  'лайн': 9651,
#  'приспосаблива': 15832,
#  'psn': 2691,
#  'убережен': 19966,
#  'кебабчик': 8750,
#  'рожков': 17390,
#  'powersmart': 2661,
#  'принос': 15760,
#  'направ': 11071,
#  'неубиваем': 11749,
#  'напролет': 11080,
#  'закачк': 7419,
#  'распаковыван': 16971,
#  'тибальн': 19544,
#  'слдела': 18208,
#  'приеха': 15646,
#  'жест': 7065,
#  'времен': 5136,
#  'dbv': 1689,
#  'шестерн': 21357,
#  'мейд': 10221,
#  'экономичн': 21584,
#  'картофелечистк': 8649,
#  'ер': 6973,
#  'разморозк': 16821,
#  'бриз': 4216,
#  'календар': 8543,
#  'измельча': 8186,
#  'межблочн': 10214,
#  'разблокир': 16675,
#  'моет': 10505,
#  'декальцинац': 6309,
#  'отсовет': 13043,
#  'порядочн': 15024,
#  '17000': 257,
#  'дерган': 6346,
#  '2ч': 577,
#  'пожар': 14489,
#  'видок': 4688,
#  'даж': 6173,
#  'монетк': 10548,
#  'аппаратик': 3625,
#  'шестиранник': 21360,
#  'импортн': 8272,
#  '2501': 467,
#  'знает': 8015,
#  'самовольн': 17572,
#  'запира': 7643,
#  'умудр': 20224,
#  'упадет': 20247,
#  'battlefield': 1447,
#  'единовремен': 6937,
#  'подтачива': 14416,
#  'wma': 3235,
#  'помаха': 14789,
#  'supr': 2983,
#  'характристик': 20784,
#  'мчу': 10715,
#  'глюканул': 5899,
#  'коп': 9238,
#  'сиян': 18039,
#  'материнск': 10138,
#  'касательн': 8662,
#  'махнул': 10155,
#  'оттира': 13081,
#  'запчаст': 7704,
#  'рекламир': 17258,
#  'продержа': 16047,
#  'лужиц': 9879,
#  'нифиг': 11849,
#  'блюдец': 4084,
#  'небезопасн': 11292,
#  'strik': 2970,
#  'bluetooh': 1492,
#  'корридор': 9309,
#  'чстбоб': 21225,
#  'зар': 7710,
#  'матрешк': 10145,
#  '5541г': 925,
#  'достоинства': 6756,
#  'заинтригова': 7393,
#  'прошивок': 16442,
#  'sim': 2889,
#  'критер': 9460,
#  'цитрусов': 21051,
#  'тк': 19567,
#  'дятл': 6909,
#  'изпасзодова': 8214,
#  'совещан': 18470,
#  'покипел': 14578,
#  'fc': 1913,
#  'подзаряд': 14217,
#  'регулируем': 17191,
#  'аккамулятор': 3469,
#  'воздержа': 4909,
#  'jnz': 2212,
#  'придач': 15617,
#  'обноружен': 12133,
#  '1316': 167,
#  'меркнет': 10265,
#  'распостраня': 17000,
#  'посудомойк': 15138,
#  'морок': 10587,
#  'термощуп': 19490,
#  'колеблет': 8983,
#  'запрос': 7691,
#  'магаз': 9951,
#  'тут': 19895,
#  'фрез': 20710,
#  'закачиван': 7418,
#  'представьт': 15417,
#  'предохранител': 15392,
#  '2244280': 436,
#  'pcmcia': 2613,
#  'ро': 17364,
#  'тяжеляк': 19943,
#  'e818': 1806,
#  'терет': 19460,
#  'скидос': 18096,
#  '5403d': 910,
#  'оседа': 12652,
#  'решел': 17322,
#  'заземл': 7381,
#  'dragon': 1759,
#  'чег': 21108,
#  'трещ': 19784,
#  'под': 14108,
#  'mg510': 2395,
#  'втягиван': 5266,
#  'покоробл': 14595,
#  'рассохнет': 17045,
#  'подарл': 14120,
#  'дельн': 6326,
#  'прикруч': 15700,
#  'блест': 4052,
#  'нереализова': 11669,
#  'наустанавлива': 11226,
#  'регулируеш': 17193,
#  'лучш': 9891,
#  'ножниц': 11900,
#  'выреза': 5556,
#  'тесн': 19502,
#  'исполнител': 8404,
#  'расстановк': 17054,
#  'vpath': 3153,
#  'порядк': 15022,
#  'стоя': 19026,
#  'geforce': 2001,
#  'снимет': 18412,
#  'город': 5984,
#  'понижен': 14877,
#  'отчисля': 13105,
#  'разбера': 16669,
#  'касынк': 8677,
#  'fir': 1928,
#  'обстоя': 12230,
#  'самура': 17604,
#  'проигроваел': 16096,
#  'излишеств': 8178,
#  'кпк': 9373,
#  '9700': 1265,
#  'трансформац': 19720,
#  'столов': 19007,
#  'p8161': 2590,
#  'издевк': 8170,
#  'потребля': 15199,
#  'безобразн': 3905,
#  'читер': 21209,
#  '45х4': 804,
#  'пронумирова': 16202,
#  'изн': 8197,
#  'сенхайзер': 17877,
#  'немц': 11517,
#  'аудиовыход': 3707,
#  'вынима': 5480,
#  'трахтор': 19731,
#  'дот': 6766,
#  'налева': 10977,
#  'пластиков': 13876,
#  'аскетич': 3678,
#  'подклад': 14225,
#  'трикотаж': 19798,
#  'нерв': 11664,
#  'сорбик': 18615,
#  'крепк': 9434,
#  'блокиратор': 4072,
#  'протаскиван': 16333,
#  'выглажен': 5337,
#  'каренин': 8628,
#  'вятк': 5715,
#  'port': 2652,
#  'проснул': 16297,
#  '4300': 784,
#  'объединя': 12263,
#  'повис': 14039,
#  'залезл': 7494,
#  'wm': 3233,
#  'вбега': 4416,
#  'скромн': 18173,
#  '20100909162319593': 379,
#  'лучшуюсторон': 9892,
#  'матроск': 10147,
#  'эффективн': 21764,
#  'n120': 2481,
#  '6600': 1037,
#  'наверн': 10785,
#  'отполоска': 12989,
#  'каба': 8497,
#  'ретр': 17309,
#  'кусочк': 9611,
#  'херн': 20815,
#  'флакон': 20617,
#  'окисл': 12426,
#  'охлажд': 13147,
#  'обед': 12023,
#  'мает': 9971,
#  'проезжа': 16066,
#  '98': 1268,
#  'промокнет': 16184,
#  'насторожен': 11175,
#  'выкинув': 5429,
#  'cx300': 1660,
#  'системник': 18031,
#  'са': 17536,
#  'чашечек': 21100,
#  'быва': 4320,
#  'протер': 16341,
#  'кват': 8734,
#  'зависан': 7231,
#  'соковыжмалк': 18537,
#  'французск': 20709,
#  'компелкт': 9074,
#  'свобод': 17745,
#  'строк': 19080,
#  'опя': 12587,
#  'собств': 18452,
#  '340': 654,
#  'kick': 2245,
#  'постара': 15102,
#  'натяжител': 11219,
#  'сова': 18456,
#  'ограничен': 12332,
#  'экспресс': 21621,
#  'невольн': 11333,
#  'трех': 19766,
#  'гимнастик': 5848,
#  'бухан': 4312,
#  'вролн': 5143,
#  'сообщен': 18585,
#  'негерметичн': 11354,
#  'хололильник': 20902,
#  'студентк': 19090,
#  'сочн': 18690,
#  'ятелефон': 21844,
#  'антиреклам': 3606,
#  't800': 3003,
#  'метина2': 10307,
#  'mozaic': 2447,
#  'сотов': 18672,
#  'проведет': 15953,
#  'перифер': 13718,
#  'жалееш': 7005,
#  'ez': 1882,
#  'матушк': 10148,
#  'обруба': 12214,
#  'почита': 15265,
#  'испуст': 8430,
#  'бум': 4284,
#  '80м': 1170,
#  'узкот': 20122,
#  'тайм': 19298,
#  '38ххх': 690,
#  'минеральн': 10389,
#  'начнут': 11266,
#  'покомпактн': 14589,
#  '5км': 966,
#  'pavel': 2606,
#  'гнев': 5914,
#  'привыкш': 15570,
#  'водоногревател': 4885,
#  'заканчива': 7411,
#  'успеет': 20348,
#  'графит': 6043,
#  'больбол': 4142,
#  'wif': 3205,
#  'проворачива': 15985,
#  'consumersupport': 1609,
#  'рекоменд': 17262,
#  'ростов': 17422,
#  'термопот': 19479,
#  'лес': 9734,
#  'туалет': 19856,
#  'парадонтолог': 13277,
#  '9500': 1258,
#  'центробежн': 21025,
#  'плюс': 13957,
#  'потиш': 15179,
#  'исключительн': 8378,
#  'активир': 3497,
#  'бельг': 3943,
#  'вывод': 5329,
#  'матов': 10141,
#  'планк': 13864,
#  'заснувш': 7760,
#  'обмотк': 12118,
#  'стрельб': 19053,
#  'путешественник': 16533,
#  'клик': 8889,
#  'термоизоляц': 19473,
#  'ацт': 3737,
#  'поддельн': 14184,
#  'походн': 15245,
#  'рах': 17125,
#  'грив': 6076,
#  'сосет': 18640,
#  'лепестк': 9733,
#  'приговор': 15595,
#  'задержа': 7334,
#  'загерметизирова': 7267,
#  'аэродинамическ': 3748,
#  'морковк': 10576,
#  'g8710': 1987,
#  'грейпфрут': 6058,
#  'лейбл': 9716,
#  'tim': 3030,
#  'мануал': 10067,
#  'неттоп': 11745,
#  'psp': 2692,
#  'выскальзыва': 5581,
#  'внос': 4855,
#  'зареза': 7723,
#  'производ': 16105,
#  'графитов': 6044,
#  'sigma': 2885,
#  'малайз': 10007,
#  'выгляд': 5340,
#  'сторонник': 19024,
#  'многофункционал': 10466,
#  'topdevic': 3042,
#  'w610': 3167,
#  'files': 1926,
#  '5900': 947,
#  'рестора': 17305,
#  'преоблада': 15468,
#  'попрочн': 14947,
#  'l4d': 2268,
#  'школьн': 21405,
#  'свистелк': 17738,
#  'бумажк': 4287,
#  'fallout3': 1899,
#  'персональн': 13731,
#  'обрезинен': 12207,
#  'отслежива': 13038,
#  '9800gt': 1271,
#  'виснут': 4744,
#  'долголет': 6652,
#  'превосходя': 15346,
#  'почист': 15264,
#  'ferrar': 1917,
#  '3ч': 743,
#  '3d': 702,
#  'тика': 19547,
#  'откл': 12846,
#  'задач': 7322,
#  'войт': 4957,
#  'винтелятор': 4721,
#  'сборищ': 17657,
#  'надет': 10863,
#  'переназнач': 13584,
#  'nfsu': 2516,
#  'ревиз': 17171,
#  'значительн': 8033,
#  'wolfenshtein': 3240,
#  'апельсинов': 3623,
#  'фокусир': 20640,
#  'доделк': 6599,
#  'подобн': 14291,
#  'вручн': 5149,
#  'пропадан': 16206,
#  'зу': 8055,
#  'команд': 9031,
#  'неч': 11781,
#  '12990': 152,
#  'поднимет': 14282,
#  'отправля': 12994,
#  'слышн': 18287,
#  'каш': 8711,
#  'пружинк': 16458,
#  'пооткалыва': 14894,
#  'beko': 1462,
#  'тош': 19684,
#  'дешев': 6404,
#  'посыл': 15143,
#  'пргода': 15332,
#  'перетер': 13676,
#  'провод': 15972,
#  'кодек': 8949,
#  'калесик': 8544,
#  'органайзер': 12593,
#  'тнх': 19575,
#  'раскрыва': 16963,
#  'расстраив': 17057,
#  'запутыван': 7701,
#  'самотек': 17595,
#  'пронест': 16196,
#  'дырк': 6891,
#  '46': 805,
#  'добр': 6558,
#  'выполнен': 5523,
#  'звен': 7925,
#  'забивает': 7163,
#  'пинцетик': 13796,
#  'диспле': 6501,
#  'плавлен': 13847,
#  'ндавн': 11283,
#  'таможн': 19320,
#  '1мм': 336,
#  'профессионализм': 16392,
#  'привычк': 15573,
#  'чертовск': 21151,
#  'полутор': 14744,
#  'мг': 10180,
#  'перехват': 13693,
#  'эдак': 21558,
#  'успокойт': 20358,
#  'мудрост': 10651,
#  'снаруж': 18394,
#  'разъем': 16903,
#  'претендентк': 15502,
#  'эмал': 21702,
#  'заварк': 7201,
#  'сон': 18566,
#  '1625': 237,
#  '3990': 698,
#  'микрик': 10346,
#  'выпендрива': 5505,
#  'карбон': 8623,
#  'субъект': 19115,
#  '100lb': 48,
#  'позавид': 14514,
#  'перечеркнут': 13702,
#  'крорш': 9483,
#  'директ': 6484,
#  'кагб': 8510,
#  'лост': 9867,
#  '1400гр': 188,
#  'капризн': 8603,
#  'languageisoctxpar': 2276,
#  'скольк': 18127,
#  'олов': 12472,
#  'доступн': 6763,
#  'прослужет': 16280,
#  'килзон': 8778,
#  'emf': 1830,
#  'аккумик': 3474,
#  'занимательн': 7603,
#  'обрат': 12198,
#  'харизматичн': 20787,
#  'нов': 11863,
#  'измен': 8189,
#  'определен': 12549,
#  'двухядерн': 6265,
#  'оригинальн': 12614,
#  'симб': 17983,
#  '800руб': 1160,
#  'банок': 3810,
#  'форматир': 20659,
#  'подскажет': 14377,
#  'тайминг': 19300,
#  'прожилок': 16086,
#  'сальн': 17566,
#  'эн': 21705,
#  'mms': 2428,
#  'корзинк': 9272,
#  'обменива': 12111,
#  'размыт': 16824,
#  'талант': 19315,
#  'объясним': 12277,
#  'лаваш': 9631,
#  'сказывает': 18052,
#  'вкладыва': 4758,
#  'долговечн': 6645,
#  'zanuss': 3304,
#  'диапозон': 6452,
#  'невменя': 11325,
#  'паульг': 13340,
#  'пропиар': 16222,
#  'loc': 2318,
#  'стоек': 18988,
#  'планшетофон': 13868,
#  'чайковск': 21076,
#  'дарител': 6202,
#  'f500': 1890,
#  'геммор': 5805,
#  'хлор': 20860,
#  'убав': 19954,
#  'помят': 14857,
#  'ответ': 12760,
#  'грешк': 6072,
#  'фильмотек': 20585,
#  'вентиляцион': 4502,
#  'точек': 19677,
#  'воспользлва': 5038,
#  'отлетел': 12891,
#  'орга': 12592,
#  'аб': 3329,
#  'зауж': 7853,
#  'басист': 3836,
#  'кконсультант': 8848,
#  'билет': 4013,
#  'open': 2563,
#  'повел': 14018,
#  'предусмотрительн': 15429,
#  'дем': 6327,
#  'чтон': 21233,
#  'съел': 19227,
#  'hdtv': 2090,
#  'css': 1648,
#  'окрашива': 12442,
#  'бабушк': 3756,
#  'ржавет': 17331,
#  'комьюнит': 9112,
#  'план': 13857,
#  '110кг': 110,
#  'импульсн': 8275,
#  'fullspec': 1967,
#  'мульстайлер': 10667,
#  'шибк': 21365,
#  'сев': 17825,
#  '50033279': 860,
#  'галере': 5737,
#  'dv165': 1780,
#  'расходуем': 17105,
#  'побалова': 13974,
#  'ieee1394': 2156,
#  'mazda6': 2366,
#  'подковырнут': 14236,
#  'малоизвестн': 10021,
#  'ковер': 8934,
#  'черех': 21141,
#  'развел': 16703,
#  'скрыва': 18181,
#  'диагност': 6442,
#  'всеядност': 5175,
#  'передергива': 13485,
#  'сплюснут': 18779,
#  'направлен': 11073,
#  'посерф': 15039,
#  'вплотн': 5099,
#  '1333mgz': 169,
#  'помажор': 14786,
#  'pert': 2619,
#  'достаточн': 6746,
#  'проветрен': 15965,
#  'соедиен': 18504,
#  'безподобн': 3911,
#  'пристука': 15844,
#  'паштет': 13360,
#  'доб': 6545,
#  'circu': 1583,
#  'discover': 1732,
#  'расста': 17049,
#  'влия': 4813,
#  'выключа': 5439,
#  'десн': 6368,
#  'высушив': 5617,
#  'водозаборн': 4882,
#  's8500': 2821,
#  'гланв': 5879,
#  'вдал': 4439,
#  'позиционирова': 14533,
#  'носов': 11933,
#  'кровотечен': 9473,
#  's5230': 2809,
#  'праздник': 15316,
#  'трубочк': 19826,
#  'креплен': 9436,
#  'отменя': 12914,
#  'слыш': 18283,
#  'заключен': 7445,
#  'катастрофическ': 8685,
#  'герцов': 5830,
#  'полмесяц': 14671,
#  'lx': 2330,
#  'туговат': 19859,
#  'недурн': 11416,
#  'мобайл': 10476,
#  'monitor': 2436,
#  'устран': 20389,
#  '711': 1080,
#  'бетон': 3999,
#  'полаза': 14626,
#  'младш': 10431,
#  'экспозиц': 21619,
#  'ненавистноайфономобильщик': 11523,
#  'чит': 21204,
#  'произожедш': 16115,
#  'смонтирова': 18355,
#  'намудр': 11019,
#  '248': 456,
#  'стольк': 19008,
#  'приидет': 15668,
#  'готовн': 6011,
#  'коллекц': 9000,
#  'подавн': 14115,
#  'гладкост': 5869,
#  'шуруповерт': 21501,
#  'добавл': 6548,
#  'одева': 12348,
#  'буфер': 4311,
#  '1с': 338,
#  'непозволительн': 11593,
#  'роуминг': 17427,
#  'писч': 13815,
#  'ошпар': 13202,
#  'зверюг': 7933,
#  'когд': 8946,
#  'номина': 11908,
#  'задымлен': 7352,
#  'класcн': 8866,
#  '4000х3000': 753,
#  'привяжет': 15575,
#  'е1': 6911,
#  'пищат': 13836,
#  'em250': 1828,
#  'порт': 15002,
#  'музон': 10660,
#  'недружелюбн': 11414,
#  'огон': 12324,
#  'отоплен': 12959,
#  'outlook': 2578,
#  'закуточк': 7485,
#  'сопел': 18600,
#  'ополаскивател': 12534,
#  'либ': 9752,
#  'подвесн': 14147,
#  'плейер': 13905,
#  'голов': 5939,
#  'построж': 15125,
#  'неп': 11576,
#  'блеск': 4051,
#  'присягнув': 15853,
#  'скуча': 18188,
#  'электроник': 21667,
#  'эпоксидк': 21729,
#  '3недел': 738,
#  'стуч': 19102,
#  'документальн': 6632,
#  'te': 3009,
#  'самозатачива': 17577,
#  'выпуска': 5542,
#  'вока': 4959,
#  'йогурт': 8485,
#  'опор': 12539,
#  '100гр': 54,
#  'memorystick': 2381,
#  'обма': 12103,
#  'оптимизатор': 12566,
#  'противодейств': 16357,
#  'х64': 20757,
#  'вспенива': 5197,
#  'пят': 16594,
#  'литр': 9796,
#  'заж': 7361,
#  'сот': 18667,
#  'акер': 3467,
#  'xper': 3279,
#  'предпочита': 15399,
#  'подключамем': 14232,
#  'потек': 15153,
#  'электриз': 21641,
#  'грамот': 6031,
#  'кратк': 9414,
#  'оплетк': 12525,
#  'мно': 10446,
#  'отвлек': 12769,
#  'холодильник': 20897,
#  'дизаин': 6465,
#  'крыльчатк': 9520,
#  'высвет': 5572,
#  'соответсв': 18590,
#  'шумн': 21491,
#  'идущ': 8122,
#  'магизинчик': 9957,
#  'приготовлен': 15608,
#  'denon': 1712,
#  '127': 142,
#  'turbocach': 3065,
#  '5d': 953,
#  '3хжильн': 742,
#  'безлимитн': 3898,
#  'соглас': 18488,
#  'представител': 15411,
#  'царапа': 20975,
#  'австралийск': 3351,
#  'чад': 21070,
#  'женщин': 7059,
#  'гамм': 5748,
#  'бензогенератор': 3945,
#  'уезжа': 20097,
#  'заплонирова': 7661,
#  'борьб': 4172,
#  'определител': 12550,
#  'дяд': 6908,
#  '1411': 191,
#  'разлочен': 16789,
#  'тверд': 19361,
#  'зависнет': 7234,
#  'нравет': 11961,
#  'нахаляв': 11234,
#  'ложн': 9832,
#  'попс': 14949,
#  'утомительн': 20419,
#  'колодц': 9008,
#  'стучат': 19104,
#  'wporta': 3246,
#  'откручива': 12872,
#  'hotpoint': 2119,
#  'обыкновен': 12282,
#  'сельдер': 17855,
#  '5г': 957,
#  'заката': 7413,
#  'выжимк': 5399,
#  'распуска': 17015,
#  'обыгрыв': 12280,
#  'этотн': 21755,
#  'возникш': 4936,
#  'гиг': 5836,
#  'панасоник': 13257,
#  'перемешиван': 13572,
#  'мсаф': 10643,
#  'установщик': 20375,
#  'времяпрепровожден': 5137,
#  'перебрасыва': 13421,
#  'гаразд': 5756,
#  'сортировк': 18632,
#  'высыпан': 5621,
#  'непредсказуем': 11616,
#  'спасиб': 18711,
#  'полузаморожен': 14732,
#  'ушн': 20486,
#  'взбиван': 4585,
#  'u2': 3073,
#  'превира': 15342,
#  '18мм': 285,
#  'перс': 13725,
#  'жижен': 7094,
#  'пример': 15730,
#  'вблиз': 4418,
#  'aser': 1380,
#  'mhz': 2399,
#  'завоевыва': 7243,
#  'подлов': 14256,
#  'natur': 2499,
#  'полок': 14695,
#  'бурит': 4296,
#  'потянул': 15228,
#  'с905': 17534,
#  'разболта': 16681,
#  'констатирова': 9170,
#  '3072': 598,
#  'духот': 6872,
#  'отсвет': 13030,
#  'расчеса': 17109,
#  'чемт': 21130,
#  'уболта': 19979,
#  'квадрат': 8721,
#  'пошатыва': 15276,
#  'потребительск': 15197,
#  'wake': 3176,
#  '100mb': 49,
#  '1см': 339,
#  'отсвечива': 13031,
#  'постриг': 15120,
#  'сородич': 18624,
#  '160': 226,
#  'утятниц': 20442,
#  'иногд': 8309,
#  'сыпа': 19242,
#  'поэкспериментирова': 15294,
#  'наловч': 10992,
#  'потухл': 15221,
#  'огромн': 12339,
#  'традицион': 19702,
#  'нг': 11280,
#  'весн': 4536,
#  'сдав': 17787,
#  'ноутбук': 11940,
#  'запредельн': 7685,
#  'ребятк': 17164,
#  'редкостн': 17206,
#  'пропаха': 16212,
#  'пострада': 15119,
#  'гранул': 6039,
#  '28000р': 508,
#  'выяерх': 5697,
#  'кофеаппарат': 9346,
#  'устаноевлен': 20376,
#  'нан': 11024,
#  'печата': 13760,
#  'заболел': 7174,
#  'plus': 2646,
#  'gorenj': 2022,
#  'многодетн': 10452,
#  'прерыван': 15487,
#  'пластмасов': 13884,
#  'понаберут': 14858,
#  'искажа': 8373,
#  'улетел': 20166,
#  'выветр': 5326,
#  'плач': 13897,
#  'gtx150': 2046,
#  '1го': 325,
#  'дворец': 6245,
#  'восторг': 5056,
#  'пачек': 13355,
#  'мануальн': 10068,
#  'кнопочк': 8923,
#  'возросл': 4945,
#  'досрочн': 6731,
#  'коэффициент': 9371,
#  'псп': 16485,
#  'просмотрщик': 16293,
#  'фиф': 20602,
#  'поверга': 14020,
#  'аэрогрил': 3747,
#  'нос': 11928,
#  'перемещ': 13573,
#  'жэ': 7152,
#  'шинкует': 21379,
#  'исч': 8460,
#  'погружа': 14102,
#  'бютуз': 4347,
#  'дул': 6856,
#  '60000рубл': 986,
#  'перфорац': 13734,
#  'санхейзер': 17622,
#  'шапун': 21284,
#  'кастрюлек': 8672,
#  'ht': 2124,
#  'четырех': 21170,
#  'волнова': 4972,
#  'zinaid': 3311,
#  'убавьт': 19958,
#  '3аправля': 711,
#  'обалдел': 12002,
#  '820': 1175,
#  '115': 113,
#  'полност': 14678,
#  'rela': 2753,
#  'перемолол': 13576,
#  'тыс': 19920,
#  'стил': 18965,
#  'всеформатн': 5171,
#  'ожирен': 12403,
#  'скоп': 18136,
#  'тор': 19644,
#  'удобств': 20082,
#  'плиточк': 13929,
#  '2х2': 574,
#  'панаце': 13259,
#  'красивущ': 9397,
#  'соедин': 18505,
#  'смест': 18326,
#  'тонюсеньк': 19635,
#  'инстр': 8318,
#  'стрижен': 19067,
#  '2ух': 572,
#  'спиш': 18771,
#  'бесполезн': 3972,
#  'зат': 7802,
#  'веш': 4563,
#  'german': 2003,
#  'увлажня': 20011,
#  'декодер': 6311,
#  'мокнет': 10519,
#  'естесн': 6986,
#  'привозим': 15560,
#  '20027312': 354,
#  'kck305': 2238,
#  'ac': 1300,
#  'надавливан': 10852,
#  'разработк': 16871,
#  'сверхмашин': 17707,
#  'тыкнув': 19913,
#  'увс': 20018,
#  'интесивн': 8345,
#  'вследств': 5190,
#  'справ': 18798,
#  'потерпет': 15169,
#  'наступа': 11188,
#  'рекорд': 17270,
#  'термекс': 19466,
#  'rw': 2794,
#  'капитальн': 8596,
#  'music': 2466,
#  'аркадн': 3650,
#  'скругл': 18175,
#  'успокаива': 20355,
#  'распоряжен': 16999,
#  'программн': 16016,
#  'хепп': 20814,
#  'фуфл': 20747,
#  'сапфир': 17625,
#  'автореж': 3401,
#  'pb': 2608,
#  'инверторн': 8281,
#  'вырыв': 5568,
#  'нестандартн': 11721,
#  '6105': 1003,
#  'трехмерн': 19773,
#  'пор': 14963,
#  'кноп': 8919,
#  'попробует': 14942,
#  'сок': 18531,
#  'присоединя': 15827,
#  'заигра': 7387,
#  'качествен': 8709,
#  'принест': 15755,
#  'стояночн': 19029,
#  'затянет': 7850,
#  'солянк': 18556,
#  'добротн': 6565,
#  'сбок': 17655,
#  'бойлер': 4114,
#  'инетресн': 8302,
#  'палитр': 13241,
#  'прог': 15988,
#  'пролив': 16158,
#  'подогрев': 14298,
#  'шелохнет': 21341,
#  ...}

# %%
X_train
# Out:
# <10443x21854 sparse matrix of type '<class 'numpy.float64'>'
# 	with 394186 stored elements in Compressed Sparse Row format>

# %%
X_test
# Out:
# <5144x21854 sparse matrix of type '<class 'numpy.float64'>'
# 	with 187242 stored elements in Compressed Sparse Row format>

# %%
# We will solve the classification task as experiments showed that it has better performance over regression
y_train_clf = np.round(y_train)
b = y_train_clf.min()
y_train_clf -= b

# %%
def modelfit(alg, X_train, Y_train, useTrainCV=True, cv_folds=5, early_stopping_rounds=100):
    if useTrainCV:
        xgb_param = alg.get_xgb_params()
        xgb_param['num_class'] = len(set(Y_train))
        xgtrain = xgb.DMatrix(X_train, label=Y_train)
        cvresult = xgb.cv(xgb_param, xgtrain, num_boost_round=alg.get_params()['n_estimators'], nfold=cv_folds, 
                          stratified=True, early_stopping_rounds=early_stopping_rounds)
        print("CV results: ", cvresult)
        alg.set_params(n_estimators=cvresult.shape[0])
    
    #Fit the algorithm on the data
    alg.fit(X_train, Y_train)

# %%
clf = XGBClassifier(n_estimators=10000, learning_rate=0.04, objective='multi:softprob') 
modelfit(clf, X_train, y_train_clf)
# Out:
# CV results:        test-merror-mean  test-merror-std  train-merror-mean  train-merror-std
# 0             0.396148         0.004969           0.383918          0.001825
# 1             0.393754         0.003844           0.382146          0.003187
# 2             0.394809         0.001443           0.383438          0.002447
# 3             0.393467         0.002859           0.382601          0.003442
